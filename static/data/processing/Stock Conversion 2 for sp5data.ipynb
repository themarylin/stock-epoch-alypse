# %%
import pandas as pd

# %%
csv_path = "EOD_20181027_v1.csv"
df = pd.read_csv(csv_path)

# %%
csv_path2 = "SPY_All_Holdings.csv"
spy_df = pd.read_csv(csv_path2)

# %%
df.columns = ['adj_close','stock','date','records']
stock_df = df[['date','adj_close','stock']]

# %%
stock_df.head(100)
# Out:
#           date  adj_close stock
# 0   10/23/2014     65.920  ADBE
# 1   10/24/2014     67.010  ADBE
# 2   10/27/2014     67.030  ADBE
# 3   10/28/2014     68.370  ADBE
# 4   10/29/2014     67.930  ADBE
# 5   10/30/2014     68.570  ADBE
# 6   10/31/2014     70.120  ADBE
# 7    11/3/2014     69.910  ADBE
# 8    11/4/2014     71.070  ADBE
# 9    11/5/2014     71.370  ADBE
# 10   11/6/2014     72.100  ADBE
# 11   11/7/2014     71.600  ADBE
# 12  11/10/2014     71.700  ADBE
# 13  11/11/2014     71.700  ADBE
# 14  11/12/2014     71.410  ADBE
# 15  11/13/2014     71.720  ADBE
# 16  11/14/2014     71.420  ADBE
# 17  11/17/2014     69.970  ADBE
# 18  11/18/2014     70.830  ADBE
# 19  11/19/2014     70.820  ADBE
# 20  11/20/2014     70.440  ADBE
# 21  11/21/2014     71.320  ADBE
# 22  11/24/2014     71.225  ADBE
# 23  11/25/2014     72.000  ADBE
# 24  11/26/2014     72.980  ADBE
# 25  11/28/2014     73.680  ADBE
# 26   12/1/2014     73.750  ADBE
# 27   12/2/2014     73.470  ADBE
# ...

# %%
spy_df.head()
# Out:
#                               Name Identifier    Weight  \
# 0                       Apple Inc.       AAPL  4.413999
# 1            Microsoft Corporation       MSFT  3.636908
# 2                  Amazon.com Inc.       AMZN  3.198155
# 3  Berkshire Hathaway Inc. Class B      BRK.B  1.724556
# 4                Johnson & Johnson        JNJ  1.626871
#
#                    Sector  Shares Held
# 0  Information Technology     51122460
# 1  Information Technology     85489150
# 2  Consumer Discretionary      4568331
# 3              Financials     21735832
# 4             Health Care     29909192

# %%
spy_list = spy_df['Identifier'].tolist()

# %%
spy_list
# Out:
# ['AAPL',
#  'MSFT',
#  'AMZN',
#  'BRK.B',
#  'JNJ',
#  'FB',
#  'JPM',
#  'GOOG',
#  'XOM',
#  'GOOGL',
#  'PFE',
#  'UNH',
#  'V',
#  'BAC',
#  'VZ',
#  'WFC',
#  'PG',
#  'T',
#  'CVX',
#  'CSCO',
#  'HD',
#  'INTC',
#  'BA',
#  'MA',
#  'MRK',
#  'KO',
#  'DIS',
#  'CMCSA',
#  'C',
#  'PEP',
#  'WMT',
#  'PM',
#  'NFLX',
#  'MCD',
#  'ORCL',
#  'NVDA',
#  'MDT',
#  'ADBE',
#  'ABBV',
#  'DWDP',
#  'AMGN',
#  'MO',
#  'ABT',
#  'IBM',
#  'HON',
#  'MMM',
#  'CRM',
#  'UNP',
#  'LLY',
#  'GE',
#  'PYPL',
#  'ACN',
#  'COST',
#  'AVGO',
#  'NKE',
#  'UTX',
#  'TMO',
#  'TXN',
#  'GILD',
#  'QCOM',
#  'BKNG',
#  'NEE',
#  'BMY',
#  'SBUX',
#  'LOW',
#  'COP',
#  'USB',
#  'LMT',
#  'GS',
#  'UPS',
#  'SLB',
#  'AXP',
#  'CVS',
#  'ANTM',
#  'CAT',
#  'AMT',
#  'TJX',
#  'WBA',
#  'AET',
#  'EOG',
#  'BDX',
#  'ADP',
#  'DHR',
#  'CME',
#  'MDLZ',
#  'BIIB',
#  'DUK',
#  'MS',
#  'AGN',
#  'CB',
#  'CHTR',
#  'ISRG',
#  'SPG',
#  'PNC',
#  'CL',
#  'CSX',
#  'INTU',
#  'ATVI',
# ...

# %%
filter_df = stock_df[stock_df['stock'].isin(spy_list)]

# %%
filter_df
# Out:
#                 date  adj_close stock
# 0         10/23/2014  65.920000  ADBE
# 1         10/24/2014  67.010000  ADBE
# 2         10/27/2014  67.030000  ADBE
# 3         10/28/2014  68.370000  ADBE
# 4         10/29/2014  67.930000  ADBE
# 5         10/30/2014  68.570000  ADBE
# 6         10/31/2014  70.120000  ADBE
# 7          11/3/2014  69.910000  ADBE
# 8          11/4/2014  71.070000  ADBE
# 9          11/5/2014  71.370000  ADBE
# 10         11/6/2014  72.100000  ADBE
# 11         11/7/2014  71.600000  ADBE
# 12        11/10/2014  71.700000  ADBE
# 13        11/11/2014  71.700000  ADBE
# 14        11/12/2014  71.410000  ADBE
# 15        11/13/2014  71.720000  ADBE
# 16        11/14/2014  71.420000  ADBE
# 17        11/17/2014  69.970000  ADBE
# 18        11/18/2014  70.830000  ADBE
# 19        11/19/2014  70.820000  ADBE
# 20        11/20/2014  70.440000  ADBE
# 21        11/21/2014  71.320000  ADBE
# 22        11/24/2014  71.225000  ADBE
# 23        11/25/2014  72.000000  ADBE
# ...

# %%
filter_df['date']=pd.to_datetime(filter_df.date)
# Out:
# C:\Users\Jeff\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
filter_df.dtypes
# Out:
# date         datetime64[ns]
# adj_close           float64
# stock                object
# dtype: object

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql://hjjms:uscdata123@stockml.cdav1uud78om.us-east-2.rds.amazonaws.com/stockAnalysis')
filter_df.to_sql('sp5data', con=engine)
# Out:
# C:\Users\Jeff\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py:507: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, which will be replaced by UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   cursor.execute(statement, parameters)
