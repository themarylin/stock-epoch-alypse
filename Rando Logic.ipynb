# %%
import os
import os.path
import rando

from dotenv import load_dotenv

from flask import Flask
from flask import jsonify
from flask import request
from flask import url_for
from flask import render_template

from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import text
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import and_

import pymysql
import json
from decimal import *

from flask.json import JSONEncoder
from datetime import date

from random import random, randint
import pandas as pd



pymysql.install_as_MySQLdb()
load_dotenv()
# Out:
# True

# %%
username = os.getenv("DATABASE_USERNAME")
password = os.getenv("DATABASE_PASSWORD")
host = os.getenv("DATABASE_HOST")
port = os.getenv("DATABASE_PORT")
database = os.getenv("DATABASE_NAME")

# %%
connection = f"mysql://{username}:{password}@{host}:{port}/{database}"

Base = automap_base()
engine = create_engine(connection, pool_recycle=1)
conn = engine.connect()
# Out:
# C:\Users\Jeff\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, which will be replaced by UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)

# %%
Base.prepare(engine, reflect=True)
StockData = Base.classes.sp5data
session = Session(bind=engine)

# %%
# session = Session(bind=engine)
# results = session.query(StockData.date, StockData.adj_close).filter_by(stock="DIS")

# %%
# result.date.strftime("%Y-%m-%d")
# SELECT DISTINCT stock
# FROM sp5data
# WHERE `date` BETWEEN '2015-10-01' AND '2018-09-28'
# AND adj_close IS NOT NULL;

# status_counts = db.session.query(BarBaz.status, db.func.count(BarBaz.id).label('count_id')
# ).filter(db.not_(db.or_(BarBaz.name == 'Foo', BarBaz.name == 'Bar'))
# ).group_by(BarBaz.status
# ).all()

# %%
# session.query(StockData.stock).filter(and_(StockData.date.between('2015-10-01', '2018-09-28'), StockData.adj_close.isnot(None))).distinct()
# session.query(q.distinct())

# %%
# q = session.query(StockData.stock).filter(StockData.date.between('2015-10-01', '2018-09-28'), StockData.adj_close.isnot(None))
# session.query(q.distinct().first())

# %%
# # import str
# rand_stock_str = str(rand_stock)
# # print(rand_stock_str)
# a = rand_stock_str[rand_stock_str.find("(")+1:rand_stock_str.find(",")]
# print(a)

# %%
# for line in lines:
# line = "'APA,'"

# line = line[1:-2]
# print(line)

# %%
stk_list = []
for stk in session.query(StockData.stock).filter(and_(StockData.date.between('2015-09-30', '2018-09-28'), StockData.adj_close.isnot(None))).distinct():
#     stk_clean = str(stk)[str(stk).find("(")+1:str(stk).find(",")]
    stk_clean = str(stk)[2:-3]
    stk_list.append(stk_clean)

# stk_list

# %%
# len(stk_list)
# stk_list[0]

# %%
rand_stock_num = randint(0, len(stk_list)-1)
# print(rand_stock)
rand_stock = stk_list[rand_stock_num]
print(rand_stock)
# print('AKAM')
# Out:
# M

# %%
# sp500_stocks = session.query(StockData.stock).group_by(.location).count()
# print(locations)

# %%
# for i in range(10):
#     i = random() < 0.5
#     if i == False:
#         print(0)
#     else:
#         print(1)

# %%
# stock_1 = session.query(StockData.date, StockData.adj_close).filter(StockData.stock == 'DIS', StockData.date.between('2015-10-01', '2018-09-28'))

# %%
stk_rand_df = pd.DataFrame(columns=['stock','date','adj_close','comp_earning','adj_comp_earning'])
stk_rand_stock_list =[]
stk_rand_date_list =[]
stk_rand_adj_close_list =[]
stk_rand_comp_earning_list =[]

# %%
# rand_stock = 'EXR'

# %%
# kwargs = {'stock': rand_stock}
# for stk_rand in session.query(StockData.date,StockData.stock,StockData.adj_close).filter_by(**kwargs).filter(StockData.date.between('2015-09-30', '2018-09-28')):
#     stk_rand_date_list.append(stk_rand.date)
# stk_rand_date_list

# %%
# rand_stock

# %%
prev_stock = 0
curr_comp_earn = 1
prev_adj_close = 0
kwargs = {'stock': rand_stock}
for stk_rand in session.query(StockData.date,StockData.stock,StockData.adj_close).filter_by(**kwargs).filter(StockData.date.between('2015-09-30', '2018-09-28')):
    stk_rand_stock_list.append(stk_rand.stock)
    stk_rand_date_list.append(stk_rand.date)
    stk_rand_adj_close_list.append(stk_rand.adj_close)
    curr_stock = random() < 0.5
    if curr_stock == False:
        curr_stock= 0
    else:
        curr_stock= 1
    sellbuy_scen = random() < 0.5
    if sellbuy_scen == False:
        sellbuy_scen= 0
    else:
        sellbuy_scen= 1
#     print(f'date:{stk_rand.date}')        
#     print(f'current stock value:{curr_stock}')
#     print(f'previous stock value:{prev_stock}')
#     print(f'sell/buy scenario stock value:{sellbuy_scen}') 
    
    if prev_adj_close == 0:
        prev_adj_close = stk_rand.adj_close
    
    curr_adj_close = stk_rand.adj_close
    
#     print(f'previous adj close:{prev_adj_close}')
#     print(f'curr adj close:{curr_adj_close}')
    
    if prev_stock == 0 and curr_stock == 0:
#         print(f'Current Compound Earnings:{curr_comp_earn}')            
        stk_rand_comp_earning_list.append(curr_comp_earn)
        prev_adj_close=curr_adj_close
        continue
    if prev_stock == 0 and curr_stock == 1:
        prev_stock = 1
#         print(f'Current Compound Earnings:{curr_comp_earn}')            
        stk_rand_comp_earning_list.append(curr_comp_earn)   
        prev_adj_close=curr_adj_close        
        continue
    if prev_stock == 1 and curr_stock == 1:
#         print(f'Current Compound Earnings:{curr_comp_earn}')            
        stk_rand_comp_earning_list.append(curr_comp_earn) 
        prev_adj_close=curr_adj_close        
        continue
    if prev_stock == 1 and curr_stock == 0:
        if sellbuy_scen == 0:
            curr_comp_earn=(((curr_adj_close-prev_adj_close)/prev_adj_close)+1)*curr_comp_earn
            prev_stock = 0
        else:
            curr_comp_earn=(((curr_adj_close-prev_adj_close)/prev_adj_close)+1)*curr_comp_earn
        
#     print(f'Current Compound Earnings:{curr_comp_earn}')            
    stk_rand_comp_earning_list.append(curr_comp_earn)
    prev_adj_close=curr_adj_close
        
print(f'Final Compound Earnings:{curr_comp_earn}')
# Out:
# Final Compound Earnings:0.8620785761346861166182177443

# %%
stk_rand_df['stock']=stk_rand_stock_list
stk_rand_df['date']=stk_rand_date_list
stk_rand_df['adj_close']=stk_rand_adj_close_list
stk_rand_df['comp_earning']=stk_rand_comp_earning_list

# %%
stk_rand_adj_comp_earning_list = [value-1 for value in stk_rand_comp_earning_list]
# for value in range(len(stk_rand_comp_earning_list)):
#     curr_value = stk_rand_comp_earning_list[value]-1
#     stk_rand_adj_comp_earning_list.append(curr_value)

# %%
len(stk_rand_adj_comp_earning_list)
# 737     M 2018-09-04  36.0096518310  0.8878033885377867786608240761
# 738     M 2018-09-05  35.4258185090  0.8734092143301191172624561494
# 739     M 2018-09-06  34.9904173880  0.8626745759500785436819406083
# 740     M 2018-09-07  35.1388495880  0.8663341117530510363178008613
# 741     M 2018-09-10  35.6039371500  0.8778006573183407036074805852
# 742     M 2018-09-11  36.0096518310  0.8778006573183407036074805852
# 743     M 2018-09-12  36.0096518310  0.8778006573183407036074805852
# 744     M 2018-09-13  35.7400000000  0.8778006573183407036074805852
# 745     M 2018-09-14  36.2700000000  0.8908178466965925383280168106
# 746     M 2018-09-17  35.1600000000  0.8908178466965925383280168106
# 747     M 2018-09-18  35.5300000000  0.8908178466965925383280168106
# 748     M 2018-09-19  35.5500000000  0.8913192921492784896583449932
# 749     M 2018-09-20  35.1800000000  0.8913192921492784896583449932
# 750     M 2018-09-21  35.6900000000  0.8913192921492784896583449932
# 751     M 2018-09-24  34.7500000000  0.8678438050486810735675956434
# 752     M 2018-09-25  34.3800000000  0.8586034537431267714893219632
# 753     M 2018-09-26  34.8900000000  0.8586034537431267714893219632
# 754     M 2018-09-27  34.5900000000  0.8586034537431267714893219632
# 755     M 2018-09-28  34.7300000000  0.8620785761346861166182177443
#
#     adj_comp_earning
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ..               ...
# 726              NaN
# 727              NaN
# 728              NaN
# 729              NaN
# 730              NaN
# 731              NaN
# 732              NaN
# 733              NaN
# 734              NaN
# 735              NaN
# 736              NaN
# 737              NaN
# 738              NaN
# 739              NaN
# 740              NaN
# 741              NaN
# 742              NaN
# 743              NaN
# 744              NaN
# 745              NaN
# 746              NaN
# 747              NaN
# 748              NaN
# 749              NaN
# 750              NaN
# 751              NaN
# 752              NaN
# 753              NaN
# 754              NaN
# 755              NaN
#
# [756 rows x 5 columns]

# %%
stk_rand_df['adj_comp_earning']=stk_rand_df.comp_earning-1

# %%
stk_rand_df.tail(10)
# Out:
#     stock       date      adj_close                    comp_earning  \
# 746     M 2018-09-17  35.1600000000  0.8908178466965925383280168106
# 747     M 2018-09-18  35.5300000000  0.8908178466965925383280168106
# 748     M 2018-09-19  35.5500000000  0.8913192921492784896583449932
# 749     M 2018-09-20  35.1800000000  0.8913192921492784896583449932
# 750     M 2018-09-21  35.6900000000  0.8913192921492784896583449932
# 751     M 2018-09-24  34.7500000000  0.8678438050486810735675956434
# 752     M 2018-09-25  34.3800000000  0.8586034537431267714893219632
# 753     M 2018-09-26  34.8900000000  0.8586034537431267714893219632
# 754     M 2018-09-27  34.5900000000  0.8586034537431267714893219632
# 755     M 2018-09-28  34.7300000000  0.8620785761346861166182177443
#
#                     adj_comp_earning
# 746  -0.1091821533034074616719831894
# 747  -0.1091821533034074616719831894
# 748  -0.1086807078507215103416550068
# 749  -0.1086807078507215103416550068
# 750  -0.1086807078507215103416550068
# 751  -0.1321561949513189264324043566
# 752  -0.1413965462568732285106780368
# 753  -0.1413965462568732285106780368
# 754  -0.1413965462568732285106780368
# 755  -0.1379214238653138833817822557
